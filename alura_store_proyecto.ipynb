# %% [markdown]
# <a href="https://colab.research.google.com/github/Neyker8a/alura-store-proyecto/blob/main/alura_store_proyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyecto analisis de datos de las tiendas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)



tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# Explorar los datos de las tiendas

# %%
tienda2.head()
# Out:
#            Producto  Categoría del Producto    Precio  Costo de envío  \
# 0  Silla de oficina                 Muebles  283600.0         15300.0
# 1         Pandereta  Instrumentos musicales   76800.0          2300.0
# 2         Cama king                 Muebles  443300.0         23800.0
# 3         Cama king                 Muebles  906200.0         46400.0
# 4  Silla de oficina                 Muebles  397800.0         19400.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      04/08/2021  Izabela de León        Medellín             1
# 1      26/11/2020   Blanca Ramirez        Medellín             3
# 2      22/10/2021  Izabela de León         Pereira             5
# 3      04/05/2022    Maria Alfonso            Cali             5
# 4      26/02/2022    Lucas Olivera          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0               Nequi                   1  6.25184 -75.56359
# ...

# %%
tienda3.head()
# Out:
#             Producto  Categoría del Producto     Precio  Costo de envío  \
# 0   Secadora de ropa       Electrodomésticos  1285100.0         66600.0
# 1      Mesa de noche                 Muebles   290100.0         13600.0
# 2  Guitarra acústica  Instrumentos musicales   303500.0         17400.0
# 3  Balón de voleibol    Deportes y diversión    58800.0          3300.0
# 4            Armario                 Muebles   521100.0         25900.0
#
#   Fecha de Compra        Vendedor Lugar de Compra  Calificación  \
# 0      17/12/2021   Camila Rivera     Santa Marta             4
# 1      10/02/2021   Maria Alfonso            Cali             3
# 2      22/01/2023   Lucas Olivera          Bogotá             5
# 3      22/03/2022     Pedro Gomez    Barranquilla             4
# 4      12/01/2022  Blanca Ramirez          Bogotá             1
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   4  11.24079 -74.19904
# ...

# %%
tienda4.head()
# Out:
#               Producto Categoría del Producto     Precio  Costo de envío  \
# 0         Lavavajillas      Electrodomésticos  1084800.0         56000.0
# 1             Cama box                Muebles   473800.0         25400.0
# 2  Balón de baloncesto   Deportes y diversión    23700.0             0.0
# 3  Modelado predictivo                 Libros    57700.0          1300.0
# 4          Auriculares           Electrónicos   138900.0          5600.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      11/11/2022    Rafael Acosta          Bogotá             4
# 1      03/01/2020  Izabela de León          Cúcuta             5
# 2      25/12/2022    Maria Alfonso        Medellín             5
# 3      23/11/2021    Lucas Olivera        Medellín             3
# 4      25/04/2022   Blanca Ramirez          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0  Tarjeta de crédito                   3  4.60971 -74.08175
# ...

# %% [markdown]
# Analisis exploratorio de datos

# %%
tienda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %%
tienda2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %%
tienda3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %%
tienda4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2358 entries, 0 to 2357
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2358 non-null   object
#  1   Categoría del Producto  2358 non-null   object
#  2   Precio                  2358 non-null   float64
#  3   Costo de envío          2358 non-null   float64
#  4   Fecha de Compra         2358 non-null   object
#  5   Vendedor                2358 non-null   object
#  6   Lugar de Compra         2358 non-null   object
#  7   Calificación            2358 non-null   int64
#  8   Método de pago          2358 non-null   object
#  9   Cantidad de cuotas      2358 non-null   int64
#  10  lat                     2358 non-null   float64
#  11  lon                     2358 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.2+ KB

# %% [markdown]
# Los datos tienen la misma estructura en las 4 tiendas, con la unica diferencia que la tienda 4, posee 2358 registros , y el resto de tiendas posee 2359

# %% [markdown]
# # 1. Análisis de facturación

# %%
ingresoTienda = tienda["Precio"].sum()
print(f"El ingreso total de la tienda es: {ingresoTienda:,.2f}")

ingresoTienda2 = tienda2["Precio"].sum()
print(f"El ingreso total de la tienda 2 es: {ingresoTienda2:,.2f}")

ingresoTienda3 = tienda3["Precio"].sum()
print(f"El ingreso total de la tienda 3 es: {ingresoTienda3:,.2f}")

ingresoTienda4 = tienda4["Precio"].sum()
print(f"El ingreso total de la tienda 4 es: ${ingresoTienda4:,.2f}")
# Out:
# El ingreso total de la tienda es: 1,150,880,400.00
# El ingreso total de la tienda 2 es: 1,116,343,500.00
# El ingreso total de la tienda 3 es: 1,098,019,600.00
# El ingreso total de la tienda 4 es: $1,038,375,700.00

# %%
ingresos = {
    "Tienda 1": ingresoTienda,
    "Tienda 2": ingresoTienda2,
    "Tienda 3": ingresoTienda3,
    "Tienda 4": ingresoTienda4
}

print(ingresos)
# Out:
# {'Tienda 1': np.float64(1150880400.0), 'Tienda 2': np.float64(1116343500.0), 'Tienda 3': np.float64(1098019600.0), 'Tienda 4': np.float64(1038375700.0)}

# %%
plt.figure()
plt.bar(ingresos.keys(), ingresos.values())

plt.title("Ingresos Totales por Tienda")
plt.xlabel("Tienda")
plt.ylabel("Ingresos")

plt.show()

# %% [markdown]
#     Analisis de Ingresos
# En el grafico se aprecia, que la tienda 1 es la que representa mayores ingresos, y la tienda 4 la que tiene menores ingresos, lo que nos dice que esta presentado un menor desempeño

# %% [markdown]
# # 2. Ventas por categoría

# %%
t1 = tienda.copy()
t2 = tienda2.copy()
t3 = tienda3.copy()
t4 = tienda4.copy()


t1["Tienda"] = "Tienda 1"
t2["Tienda"] = "Tienda 2"
t3["Tienda"] = "Tienda 3"
t4["Tienda"] = "Tienda 4"

# Unir todas las tiendas en un solo DataFrame
todas_las_tiendas = pd.concat([t1, t2, t3, t4], ignore_index=True)

#  Agrupar por Categoría y Tienda
comparacion = (
    todas_las_tiendas.groupby(["Categoría del Producto", "Tienda"]).size().unstack().fillna(0)
)

# Agregar total global por categoría
comparacion["Total Global"] = comparacion.sum(axis=1)

# Ordenar por las categorías más vendidas globalmente
comparacion = comparacion.sort_values("Total Global", ascending=False)

# Graficar (sin la columna Total Global)
comparacion.drop(columns="Total Global").plot(kind="bar", figsize=(10,6))

plt.title("Ventas por Categoría en Cada Tienda")
plt.ylabel("Cantidad de Productos Vendidos")
plt.xlabel("Categoría")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
# Como ya tenia todas las tiendas concatenadas

calificacion_promedio= (
    todas_las_tiendas.groupby("Tienda")["Calificación"].mean()
)

print(calificacion_promedio)

ax = calificacion_promedio.plot(kind="bar")

plt.title("Calificación Promedio por Tienda")
plt.ylabel("Promedio de Calificación")
plt.xlabel("Tiendas")
plt.ylim(3,5)

for i, valor in enumerate(calificacion_promedio):
    ax.text(
        i,                 # posición horizontal
        valor + 0.05,       # posición vertical (un poco arriba)
        f"{valor:.2f}",     # formato con 2 decimales
        ha="center"         # alineación horizontal
    )
plt.show()
# Out:
# Tienda
# Tienda 1    3.976685
# Tienda 2    4.037304
# Tienda 3    4.048326
# Tienda 4    3.995759
# Name: Calificación, dtype: float64

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
ventas_producto = (
    todas_las_tiendas.groupby(["Tienda", "Producto"]).size()
)

for tienda in ventas_producto.index.levels[0]:
    ventas_tienda = ventas_producto.loc[tienda]

    mas_vendido = ventas_tienda.idxmax()
    menos_vendido = ventas_tienda.idxmin()

    valores = [ventas_tienda.max(), ventas_tienda.min()]
    productos = [mas_vendido, menos_vendido]

    plt.figure(figsize=(8, 4))
    plt.bar(productos, valores)

    for i, valor in enumerate(valores):
        plt.text(i, valor, str(valor), ha='center', va='bottom')

    plt.title(f"Productos Más y Menos Vendidos en {tienda}")
    plt.xlabel("Producto")
    plt.ylabel("Cantidad de Ventas")
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# # 5. Envío promedio por tienda
